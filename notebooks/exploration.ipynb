# %% [markdown]
# # Escrow POC — Exploration
#
# Run OCR + the Agno extractor + rule generator on the sample deeds without going through FastAPI.
#
# Prereqs: `.env` filled with `ANTHROPIC_API_KEY`; sample PDFs under `data/samples/`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

# %%
from ocr.doctr_ocr import extract_text
raw = extract_text('../data/samples/Dubai_Commercial_Sale_Deed.pdf')
print(raw[:1500])

# %%
from agents.extractor import extract_fields
fields = extract_fields(raw)
fields

# %%
from rules.generator import generate_rules
rules = generate_rules(fields)
for r in rules:
    print(r)
